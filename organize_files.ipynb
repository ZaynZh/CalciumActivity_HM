# %%
import glob
import shutil
import os
import re

root_folder = "/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/bpod"

# List of all subdirectories (non-recursive)
bpod_path_list = [
    os.path.join(root_folder, d)
    for d in os.listdir(root_folder)
    if os.path.isdir(os.path.join(root_folder, d))
]

# %%
def copy_and_rename(
    source_file: str, 
    destination_folder: str, 
    new_filename: str
) -> str:
    """
    Copies 'source_file' into 'destination_folder' and renames it to 'new_filename'.
    Returns the path of the newly created file.
    """

    # Ensure the destination folder exists (create it if not)
    os.makedirs(destination_folder, exist_ok=True)

    # Construct the full destination path, including the new file name
    destination_path = os.path.join(destination_folder, new_filename)
    
    if os.path.exists(destination_path):
        print(f"File {destination_path} already exists. Skipping copy.")
        return destination_path

    # Copy the file from source to the new destination path
    shutil.copy2(source_file, destination_path)  
    # copy2 preserves metadata. If you don't need it, you can use shutil.copy

    return destination_path

# %%
mouse_list = ['ZZ0028-LR','ZZ0028-RRL','ZZ0028-L', 'ZZ0028-LL', 'ZZ0027-R', 'ZZ0027-LR', 'ZZ0027-RR', 'ZZ0027-RRL']

# %% [markdown]
# ### bpod

# %%
for mouse in mouse_list:
    mouse_path = os.path.join(root_folder,mouse)
    for stage in os.listdir(mouse_path):

        if stage == 'unity_stage1led_v3_high':
            new_stagename = 'single_mouse_LED_reward_high'
            session_path = os.path.join(mouse_path,stage,'Session Data')
            bpod_file_list = glob.glob(session_path+'/*.mat')
            for bpod_file in bpod_file_list:
                filename = os.path.basename(bpod_file)
                match = re.search(r'(\d{8})', filename)
                if match:
                    date = match.group(1)
                    print(date)  # e.g. "20240730"
                else:
                    print("No 8-digit date pattern found.")
                destination_folder = os.path.join('/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data',mouse, new_stagename , date, 'bpod')
                new_filename = mouse + '_' + date + '_' + new_stagename +'.mat'
                copy_and_rename(bpod_file, destination_folder, new_filename)

        elif stage == 'unity_stage1led_v3_low':
            new_stagename = 'single_mouse_LED_reward_low'
            session_path = os.path.join(mouse_path,stage,'Session Data')
            bpod_file_list = glob.glob(session_path+'/*.mat')
            for bpod_file in bpod_file_list:
                filename = os.path.basename(bpod_file)
                match = re.search(r'(\d{8})', filename)
                if match:
                    date = match.group(1)
                    print(date)  # e.g. "20240730"
                else:
                    print("No 8-digit date pattern found.")
                destination_folder = os.path.join('/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data',mouse, new_stagename , date, 'bpod')
                new_filename = mouse + '_' + date + '_' + new_stagename +'.mat'
                copy_and_rename(bpod_file, destination_folder, new_filename)

        elif stage == 'unity_stage2center_v4_high':
            new_stagename = 'single_mouse_center_return_high'
            session_path = os.path.join(mouse_path,stage,'Session Data')
            bpod_file_list = glob.glob(session_path+'/*.mat')
            for bpod_file in bpod_file_list:
                filename = os.path.basename(bpod_file)
                match = re.search(r'(\d{8})', filename)
                if match:
                    date = match.group(1)
                    print(date)  # e.g. "20240730"
                else:
                    print("No 8-digit date pattern found.")
                destination_folder = os.path.join('/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data',mouse, new_stagename , date, 'bpod')
                new_filename = mouse + '_' + date + '_' + new_stagename +'.mat'
                copy_and_rename(bpod_file, destination_folder, new_filename)       

        elif stage == 'unity_stage2center_v4_low':
            new_stagename = 'single_mouse_center_return_low'
            session_path = os.path.join(mouse_path,stage,'Session Data')
            bpod_file_list = glob.glob(session_path+'/*.mat')
            for bpod_file in bpod_file_list:
                filename = os.path.basename(bpod_file)
                match = re.search(r'(\d{8})', filename)
                if match:
                    date = match.group(1)
                    print(date)  # e.g. "20240730"
                else:
                    print("No 8-digit date pattern found.")
                destination_folder = os.path.join('/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data',mouse, new_stagename , date, 'bpod')
                new_filename = mouse + '_' + date + '_' + new_stagename +'.mat'
                copy_and_rename(bpod_file, destination_folder, new_filename)      
        
        elif stage == 'unity_stage3test_v1':
            new_stagename = 'single_mouse_multiple_rewards'
            session_path = os.path.join(mouse_path,stage,'Session Data')
            bpod_file_list = glob.glob(session_path+'/*.mat')
            for bpod_file in bpod_file_list:
                filename = os.path.basename(bpod_file)
                match = re.search(r'(\d{8})', filename)
                if match:
                    date = match.group(1)
                    print(date)  # e.g. "20240730"
                else:
                    print("No 8-digit date pattern found.")
                destination_folder = os.path.join('/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data',mouse, new_stagename , date, 'bpod')
                new_filename = mouse + '_' + date + '_' + new_stagename +'.mat'
                copy_and_rename(bpod_file, destination_folder, new_filename)   

        elif stage == 'backup_stage2center':
            new_stagename = 'single_mouse_center_return'
            session_path = os.path.join(mouse_path,stage,'Session Data')
            bpod_file_list = glob.glob(session_path+'/*.mat')
            for bpod_file in bpod_file_list:
                filename = os.path.basename(bpod_file)
                match = re.search(r'(\d{8})', filename)
                if match:
                    date = match.group(1)
                    print(date)
                else:
                    print("No 8-digit date pattern found.")
                destination_folder = os.path.join('/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data',mouse, new_stagename , date, 'bpod')
                new_filename = mouse + '_' + date + '_' + new_stagename +'.mat'
                copy_and_rename(bpod_file, destination_folder, new_filename)

        elif stage == 'backup_stage1led':
            new_stagename = 'single_mouse_LED_reward'
            session_path = os.path.join(mouse_path,stage,'Session Data')
            bpod_file_list = glob.glob(session_path+'/*.mat')
            for bpod_file in bpod_file_list:
                filename = os.path.basename(bpod_file)
                match = re.search(r'(\d{8})', filename)
                if match:
                    date = match.group(1)
                    print(date)
                else:
                    print("No 8-digit date pattern found.")
                destination_folder = os.path.join('/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data',mouse, new_stagename , date, 'bpod')
                new_filename = mouse + '_' + date + '_' + new_stagename +'.mat'
                copy_and_rename(bpod_file, destination_folder, new_filename)
    print(f'Mouse:{mouse} bpod files transferred')
# Out:
# 20240731
# 20240806
# 20240726
# 20240805
# 20240730
# 20240729
# 20240801
# 20240802
# 20240806
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LR/single_mouse_LED_reward_high/20240806/bpod/ZZ0022-LR_20240806_single_mouse_LED_reward_high.mat already exists. Skipping copy.
# 20240829
# 20240816
# 20240819
# 20240830
# 20240807
# 20241024
# 20240827
# 20240822
# 20240920
# 20240812
# 20240821
# 20240813
# 20240906
# 20240927
# 20240823
# 20241018
# 20241025
# 20240826
# 20240902
# 20241028
# 20240808
# 20240822
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LR/single_mouse_center_return_high/20240822/bpod/ZZ0022-LR_20240822_single_mouse_center_return_high.mat already exists. Skipping copy.
# 20241017
# 20240909
# 20240924
# 20240913
# 20240923
# 20241021
# 20240903
# 20240815
# Mouse:ZZ0022-LR bpod files transferred
# 20241230
# 20250102
# 20250110
# 20250109
# 20241227
# 20250107
# 20250106
# 20240918
# 20240823
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_low/20240823/bpod/ZZ0022-LL_20240823_single_mouse_center_return_low.mat already exists. Skipping copy.
# 20240920
# 20240923
# 20240827
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_low/20240827/bpod/ZZ0022-LL_20240827_single_mouse_center_return_low.mat already exists. Skipping copy.
# 20241018
# 20240822
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_low/20240822/bpod/ZZ0022-LL_20240822_single_mouse_center_return_low.mat already exists. Skipping copy.
# 20240927
# 20240902
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_low/20240902/bpod/ZZ0022-LL_20240902_single_mouse_center_return_low.mat already exists. Skipping copy.
# 20241025
# 20240827
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_low/20240827/bpod/ZZ0022-LL_20240827_single_mouse_center_return_low.mat already exists. Skipping copy.
# 20240903
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_low/20240903/bpod/ZZ0022-LL_20240903_single_mouse_center_return_low.mat already exists. Skipping copy.
# 20240823
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_low/20240823/bpod/ZZ0022-LL_20240823_single_mouse_center_return_low.mat already exists. Skipping copy.
# 20241024
# 20241028
# 20241017
# 20240826
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_low/20240826/bpod/ZZ0022-LL_20240826_single_mouse_center_return_low.mat already exists. Skipping copy.
# 20240924
# 20240913
# 20240906
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_low/20240906/bpod/ZZ0022-LL_20240906_single_mouse_center_return_low.mat already exists. Skipping copy.
# 20241021
# 20240821
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_low/20240821/bpod/ZZ0022-LL_20240821_single_mouse_center_return_low.mat already exists. Skipping copy.
# 20240730
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_LED_reward_high/20240730/bpod/ZZ0022-LL_20240730_single_mouse_LED_reward_high.mat already exists. Skipping copy.
# 20240805
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_LED_reward_high/20240805/bpod/ZZ0022-LL_20240805_single_mouse_LED_reward_high.mat already exists. Skipping copy.
# 20240726
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_LED_reward_high/20240726/bpod/ZZ0022-LL_20240726_single_mouse_LED_reward_high.mat already exists. Skipping copy.
# 20240729
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_LED_reward_high/20240729/bpod/ZZ0022-LL_20240729_single_mouse_LED_reward_high.mat already exists. Skipping copy.
# 20240801
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_LED_reward_high/20240801/bpod/ZZ0022-LL_20240801_single_mouse_LED_reward_high.mat already exists. Skipping copy.
# 20240731
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_LED_reward_high/20240731/bpod/ZZ0022-LL_20240731_single_mouse_LED_reward_high.mat already exists. Skipping copy.
# 20240802
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_LED_reward_high/20240802/bpod/ZZ0022-LL_20240802_single_mouse_LED_reward_high.mat already exists. Skipping copy.
# 20240806
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_LED_reward_high/20240806/bpod/ZZ0022-LL_20240806_single_mouse_LED_reward_high.mat already exists. Skipping copy.
# 20240830
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_multiple_rewards/20240830/bpod/ZZ0022-LL_20240830_single_mouse_multiple_rewards.mat already exists. Skipping copy.
# 20240819
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_multiple_rewards/20240819/bpod/ZZ0022-LL_20240819_single_mouse_multiple_rewards.mat already exists. Skipping copy.
# 20240816
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_multiple_rewards/20240816/bpod/ZZ0022-LL_20240816_single_mouse_multiple_rewards.mat already exists. Skipping copy.
# 20240829
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_multiple_rewards/20240829/bpod/ZZ0022-LL_20240829_single_mouse_multiple_rewards.mat already exists. Skipping copy.
# 20240812
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_high/20240812/bpod/ZZ0022-LL_20240812_single_mouse_center_return_high.mat already exists. Skipping copy.
# 20240807
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_high/20240807/bpod/ZZ0022-LL_20240807_single_mouse_center_return_high.mat already exists. Skipping copy.
# 20240909
# 20240918
# 20240813
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_high/20240813/bpod/ZZ0022-LL_20240813_single_mouse_center_return_high.mat already exists. Skipping copy.
# 20240808
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_high/20240808/bpod/ZZ0022-LL_20240808_single_mouse_center_return_high.mat already exists. Skipping copy.
# 20240815
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data/ZZ0022-LL/single_mouse_center_return_high/20240815/bpod/ZZ0022-LL_20240815_single_mouse_center_return_high.mat already exists. Skipping copy.
# Mouse:ZZ0022-LL bpod files transferred
# 20241226
# 20241230
# 20241227
# 20250102
# 20250106
# 20250107
# 20241212
# 20241217
# 20241213
# 20241219
# 20241211
# 20241127
# 20241115
# 20241120
# 20241125
# 20241112
# 20241121
# 20241126
# 20241122
# 20241118
# 20241114
# 20241223
# 20241220
# 20250109
# 20241209
# 20250110
# 20241210
# 20241202
# 20241204
# 20241203
# 20241129
# 20241206
# 20241205
# 20241226
# Mouse:ZZ0026-RR bpod files transferred

# %% [markdown]
# ### wavesurfer

# %%
for root, dirs, files in os.walk('/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/single_mouse_data'):
    # Check if 'wavesurfer' is one of the subdirectories
    if 'wavesurfer' in dirs:
        wavesurfer_path = os.path.join(root, 'wavesurfer')
        print(f"Deleting: {wavesurfer_path}")
        shutil.rmtree(wavesurfer_path)  # Remove wavesurfer folder entirely

        # Also remove 'wavesurfer' from 'dirs' list so os.walk() doesn't try to recurse into it
        dirs.remove('wavesurfer')

# %%
dpath = '/Volumes/Hiroshi Makino/User/Zeyuan/Data/Wavesurfer_data'
for mouse in mouse_list:
    ws_glob_list = glob.glob(dpath+'/'+mouse+'*')
    mouse_pattern = re.compile(rf"{mouse}($|[^A-Za-z])") 
    ws_filepath_list = []
    for path in ws_glob_list:
        if os.path.isfile(path):
            filename = os.path.basename(path)
            if mouse_pattern.search(filename):
                ws_filepath_list.append(path)
    for ws_filepath in ws_filepath_list:
        match = re.search(r"(\d{4}-\d{2}-\d{2})", ws_filepath)
        if match:
            date = match.group(1)
            date = date.replace("-","")
            print(date)  # "20240816"
        else:
            print("No date found.")
        organized_mouse_dpath = os.path.join('/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/' + mouse)
        stage_list = os.listdir(organized_mouse_dpath)
        for stage in stage_list:
            stage_path = os.path.join(organized_mouse_dpath, stage)
            destination_folder = os.path.join(stage_path, date)
            new_filename = mouse + "_" + date + "" + ".h5"
            if os.path.isdir(destination_folder):
                destination_folder = os.path.join(destination_folder, 'wavesurfer')
                copy_and_rename(ws_filepath, destination_folder, new_filename)
    print(f'Mouse:{mouse} wavesurfer files transferred')
# Out:
# 20250325
# 20250307
# 20250514
# 20250424
# 20250509
# 20250330
# 20250402
# 20250411
# 20250321
# 20250309
# 20250310
# 20250602
# 20250422
# 20250305
# 20250614
# 20250515
# 20250425
# 20250618
# 20250609
# 20250429
# 20250511
# 20250421
# 20250520
# 20250502
# 20250409
# 20250401
# 20250311
# 20250410
# 20250513
# 20250423
# 20250504
# Mouse:ZZ0028-LR wavesurfer files transferred
# 20250422
# 20250305
# 20250516
# 20250309
# 20250310
# 20250424
# 20250514
# 20250307
# 20250509
# 20250330
# 20250402
# 20250321
# 20250411
# 20250423
# 20250513
# 20250409
# 20250311
# 20250401
# 20250410
# 20250425
# 20250515
# 20250614
# 20250609
# 20250421
# 20250511
# 20250520
# Mouse:ZZ0028-RRL wavesurfer files transferred
# 20250309
# 20250310
# 20250305
# 20250512
# 20250602
# 20250422
# 20250509
# 20250617
# 20250321
# 20250411
# 20250402
# 20250330
# 20250307
# 20250514
# 20250424
# 20250409
# 20250410
# 20250401
# 20250311
# 20250522
# 20250513
# 20250423
# 20250609
# 20250429
# 20250511
# 20250421
# 20250614
# 20250425
# Mouse:ZZ0028-L wavesurfer files transferred
# 20250602
# 20250422
# 20250512
# 20250310
# 20250309
# 20250424
# 20250514
# 20250513
# 20250307
# 20250330
# 20250402
# 20250321
# 20250411
# 20250509
# 20250423
# 20250513
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/ZZ0028-LL/high_test/20250513/wavesurfer/ZZ0028-LL_20250513.h5 already exists. Skipping copy.
# 20250522
# 20250311
# 20250401
# 20250410
# 20250409
# 20250425
# 20250614
# 20250421
# 20250511
# 20250609
# Mouse:ZZ0028-LL wavesurfer files transferred
# 20241223
# 20250115
# 20250511
# 20250429
# 20250425
# 20250515
# 20250201
# 20250102
# 20250423
# 20250513
# 20241216
# 20250113
# 20250221
# 20250212
# 20250116
# 20250516
# 20241219
# 20241220
# 20250424
# 20250208
# 20241226
# 20250514
# 20241217
# 20250110
# 20250428
# 20250204
# 20250213
# Mouse:ZZ0027-R wavesurfer files transferred
# 20250218
# 20250209
# 20241227
# 20250425
# 20250217
# 20250515
# 20250210
# 20250429
# 20241223
# 20250511
# 20250203
# 20250113
# 20250423
# 20250225
# 20250513
# 20241216
# 20241219
# 20250516
# 20241220
# 20250107
# 20250428
# 20250204
# 20250114
# 20250110
# 20250424
# 20241226
# 20250514
# 20250217
# 20250109
# 20241217
# Mouse:ZZ0027-LR wavesurfer files transferred
# 20250113
# 20241216
# 20250423
# 20250207
# 20250513
# 20241223
# 20250511
# 20250429
# 20250425
# 20250515
# 20250114
# 20250428
# 20241217
# 20250109
# 20250208
# 20241226
# 20250424
# 20250226
# 20250514
# 20250110
# 20250206
# 20241219
# 20250516
# 20250202
# 20241220
# 20250220
# Mouse:ZZ0027-RR wavesurfer files transferred
# 20241216
# 20250423
# 20250207
# 20250513
# 20250203
# 20250113
# 20250425
# 20250515
# 20250210
# 20250429
# 20250214
# 20241223
# 20250115
# 20250511
# 20241217
# 20250109
# 20241226
# 20250424
# 20250514
# 20250110
# 20250428
# 20250114
# 20241219
# 20250516
# 20250211
# 20241220
# 20250206
# 20250224
# Mouse:ZZ0027-RRL wavesurfer files transferred

# %% [markdown]
# ### imaging

# %%
miniscope_dpath = '/Volumes/Hiroshi Makino/User/Zeyuan/Data/Miniscope_data'
ignored = {".DS_Store", "._.DS_Store"}
for mouse in mouse_list:
    print(f"Start to transfer {mouse} imaging files")
    mouse_path = os.path.join(miniscope_dpath, mouse)
    date_list = os.listdir(mouse_path)
    date_list = [date for date in date_list if date not in ignored]
    for date in date_list:
        print(date)
        file_path = os.path.join(mouse_path,date)
        videos = glob.glob(file_path + '/*')
        video = max(videos, key=os.path.getsize)
        date = date.replace("-","")
        organized_mouse_dpath = os.path.join('/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/' + mouse)
        stage_list = os.listdir(organized_mouse_dpath)
        for stage in stage_list:
            stage_path = os.path.join(organized_mouse_dpath, stage)
            destination_folder = os.path.join(stage_path, date)
            new_filename = mouse + "_" + date + "" + ".avi"
            if os.path.isdir(destination_folder):
                destination_folder = os.path.join(destination_folder, 'imaging')
                copy_and_rename(video, destination_folder, new_filename)
    print(f'Mouse:{mouse} imaging files transferred')
# Out:
# Start to transfer ZZ0028-LR imaging files
# 2025-04-09
# 2025-04-01
# 2025-03-11
# 2025-04-10
# 2025-05-13
# 2025-04-23
# 2025-05-04
# 2025-06-09
# 2025-04-29
# 2025-06-18
# 2025-05-11
# 2025-04-21
# 2025-05-20
# 2025-05-02
# 2025-05-15
# 2025-04-25
# 2025-06-14
# 2025-05-09
# 2025-03-30
# 2025-04-02
# 2025-04-11
# 2025-03-21
# 2025-05-14
# 2025-04-24
# 2025-03-07
# 2025-06-02
# 2025-04-22
# 2025-03-05
# 2025-03-10
# 2025-03-09
# Mouse:ZZ0028-LR imaging files transferred
# Start to transfer ZZ0028-RRL imaging files
# 2025-04-09
# 2025-04-01
# 2025-03-11
# 2025-04-10
# 2025-05-13
# 2025-04-23
# 2025-06-09
# 2025-05-11
# 2025-04-21
# 2025-05-20
# 2025-05-15
# 2025-04-25
# 2025-06-14
# 2025-05-09
# 2025-03-30
# 2025-04-02
# 2025-03-03
# 2025-04-11
# 2025-03-21
# 2025-05-14
# 2025-04-24
# 2025-03-07
# 2025-06-02
# 2025-04-22
# 2025-03-05
# 2025-03-10
# 2025-05-16
# 2025-03-09
# Mouse:ZZ0028-RRL imaging files transferred
# Start to transfer ZZ0028-L imaging files
# 2025-04-09
# 2025-04-01
# 2025-03-11
# 2025-04-10
# 2025-05-13
# 2025-04-23
# 2025-05-22
# 2025-06-09
# 2025-04-29
# 2025-05-11
# 2025-04-21
# 2025-04-25
# 2025-06-14
# 2025-06-17
# 2025-05-09
# 2025-03-30
# 2025-04-02
# 2025-03-03
# 2025-04-11
# 2025-03-21
# 2025-05-14
# 2025-04-24
# 2025-03-07
# 2025-05-12
# 2025-06-02
# 2025-04-22
# 2025-03-05
# 2025-03-10
# 2025-03-09
# Mouse:ZZ0028-L imaging files transferred
# Start to transfer ZZ0028-LL imaging files
# 2025-04-09
# 2025-04-01
# 2025-03-11
# 2025-04-10
# 2025-05-13
# 2025-04-23
# 2025-05-22
# 2025-06-09
# 2025-05-11
# 2025-04-21
# 2025-04-25
# 2025-06-14
# 2025-05-09
# 2025-03-30
# 2025-04-02
# 2025-04-11
# 2025-03-21
# 2025-05-14
# 2025-04-24
# 2025-03-07
# 2025-05-12
# 2025-06-02
# 2025-04-22
# 2025-03-10
# 2025-03-09
# Mouse:ZZ0028-LL imaging files transferred
# Start to transfer ZZ0027-R imaging files
# 2025-02-21
# 2025-01-13
# 2025-02-12
# 2025-05-13
# 2025-04-23
# 2025-02-07
# 2024-12-16
# 2025-04-29
# 2025-05-11
# 2025-01-15
# 2024-12-23
# 2025-02-01
# 2025-01-02
# 2025-05-15
# 2025-04-25
# 2025-04-28
# 2025-02-04
# 2025-03-03
# 2025-02-13
# 2025-01-10
# 2025-05-14
# 2025-04-24
# 2024-12-26
# 2025-02-08
# 2024-12-17
# 2025-01-09
# 2025-06-19
# 2025-01-16
# 2025-06-20
# 2024-12-20
# 2025-05-16
# 2024-12-19
# Mouse:ZZ0027-R imaging files transferred
# Start to transfer ZZ0027-LR imaging files
# 2025-01-13
# 2025-02-03
# 2025-02-25
# 2025-05-13
# 2025-04-23
# 2024-12-16
# 2025-04-29
# 2025-05-11
# 2024-12-23
# 2025-02-10
# 2025-05-15
# 2025-04-25
# 2024-12-27
# 2025-02-18
# 2025-04-28
# 2025-01-14
# 2025-02-04
# 2025-01-10
# 2025-05-14
# 2025-04-24
# 2024-12-26
# 2024-12-17
# 2025-01-09
# 2025-02-17
# 2025-01-07
# 2024-12-20
# 2025-05-16
# 2024-12-19
# Mouse:ZZ0027-LR imaging files transferred
# Start to transfer ZZ0027-RR imaging files
# 2025-01-13
# 2025-05-13
# 2025-04-23
# 2024-12-16
# 2025-04-29
# 2025-05-11
# 2024-12-23
# 2025-05-15
# 2025-04-25
# 2025-04-28
# 2025-01-14
# 2024-12-31
# 2025-01-10
# 2025-02-26
# 2025-05-14
# 2025-04-24
# 2024-12-26
# 2025-02-08
# 2024-12-17
# 2025-01-09
# 2025-02-06
# 2025-02-20
# 2024-12-20
# 2025-02-02
# 2025-05-16
# 2024-12-19
# Mouse:ZZ0027-RR imaging files transferred
# Start to transfer ZZ0027-RRL imaging files
# 2025-01-13
# 2025-02-03
# 2025-05-13
# 2025-04-23
# 2025-02-07
# 2024-12-16
# 2025-04-29
# 2025-05-11
# 2025-01-15
# 2024-12-23
# 2025-02-14
# 2025-05-15
# 2025-04-25
# 2024-12-27
# 2025-04-28
# 2025-01-14
# 2025-01-10
# 2025-05-14
# 2025-04-24
# 2024-12-26
# 2024-12-17
# 2025-01-09
# 2025-02-24
# 2025-02-06
# 2024-12-20
# 2025-02-11
# 2025-05-16
# 2024-12-19
# Mouse:ZZ0027-RRL imaging files transferred

# %% [markdown]
# ### Behavior

# %%
behavior_path = '/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/videos'
bpod_stage_list = ['unity_stage1led_v3', 'unity_stage2center_v4', 'unity_stage3test_v1']
# bpod_stage_list = ['backup_stage2center']
for mouse in mouse_list:
    print(f"Start to transfer {mouse} behavior files")
    for bpod_stage in bpod_stage_list:
        bpod_stage_path = os.path.join(behavior_path, bpod_stage)
        behavior_glob_list = glob.glob(bpod_stage_path + '/' + mouse + '*')
        mouse_pattern = re.compile(rf"{mouse}($|[^A-Za-z])") 
        behavior_list = []
        for path in behavior_glob_list:
            if os.path.isfile(path):
                filename = os.path.basename(path)
                if mouse_pattern.search(filename):
                    behavior_list.append(path)
        for behaivor_video in behavior_list:
            match = re.search(r'(\d{8})', behaivor_video)
            if match:
                date = match.group(1)
                date = date.replace("-","")
                print(date)  # "20240816"
            else:
                print("No date found.")
            organized_mouse_dpath = os.path.join('/Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/' + mouse)
            stage_list = os.listdir(organized_mouse_dpath)
            for stage in stage_list:
                stage_path = os.path.join(organized_mouse_dpath, stage)
                destination_folder = os.path.join(stage_path, date)
                new_filename = mouse + "_" + date + "" + ".mp4"
                if os.path.isdir(destination_folder):
                    destination_folder = os.path.join(destination_folder, 'behavior')
                    copy_and_rename(behaivor_video, destination_folder, new_filename)
    print(f'Mouse:{mouse} behaivor files transferred')
# Out:
# Start to transfer ZZ0028-LR behavior files
# 20250309
# 20250307
# 20250314
# 20250321
# 20250313
# 20250311
# 20250320
# 20250305
# 20250318
# 20250312
# 20250310
# 20250409
# 20250407
# 20250328
# 20250329
# 20250601
# 20250408
# 20250326
# 20250508
# 20250327
# 20250531
# 20250326
# 20250602
# 20250519
# 20250614
# 20250414
# 20250527
# 20250419
# 20250609
# 20250523
# 20250418
# 20250530
# 20250404
# 20250324
# 20250330
# 20250506
# 20250607
# 20250325
# 20250526
# 20250613
# 20250606
# 20250507
# 20250403
# 20250612
# 20250410
# 20250402
# 20250429
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/ZZ0028-LR/high_test/20250429/behavior/ZZ0028-LR_20250429.mp4 already exists. Skipping copy.
# 20250515
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/ZZ0028-LR/low_test/20250515/behavior/ZZ0028-LR_20250515.mp4 already exists. Skipping copy.
# 20250513
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/ZZ0028-LR/low_test/20250513/behavior/ZZ0028-LR_20250513.mp4 already exists. Skipping copy.
# 20250509
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/ZZ0028-LR/low_test/20250509/behavior/ZZ0028-LR_20250509.mp4 already exists. Skipping copy.
# 20250504
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/ZZ0028-LR/high_test/20250504/behavior/ZZ0028-LR_20250504.mp4 already exists. Skipping copy.
# 20250514
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/ZZ0028-LR/low_test/20250514/behavior/ZZ0028-LR_20250514.mp4 already exists. Skipping copy.
# 20250422
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/ZZ0028-LR/high_test/20250422/behavior/ZZ0028-LR_20250422.mp4 already exists. Skipping copy.
# 20250421
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/ZZ0028-LR/low_test/20250421/behavior/ZZ0028-LR_20250421.mp4 already exists. Skipping copy.
# 20250424
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/ZZ0028-LR/high_test/20250424/behavior/ZZ0028-LR_20250424.mp4 already exists. Skipping copy.
# 20250401
# 20250411
# 20250425
# File /Volumes/Hiroshi Makino/User/KinOn/Data/diversity_training/organized_rawdata/extra/ZZ0028-LR/high_test/20250425/behavior/ZZ0028-LR_20250425.mp4 already exists. Skipping copy.
# 20250423
# 20250511
# Mouse:ZZ0028-LR behaivor files transferred
# Start to transfer ZZ0028-RRL behavior files
# 20250312
# 20250314
# 20250320
# 20250318
# 20250309
# 20250305
# 20250310
# 20250313
# 20250311
# 20250307
# 20250321
# 20250403
# 20250408
# 20250523
# 20250606
# 20250519
# 20250607
# 20250419
# 20250330
# 20250504
# 20250407
# 20250417
# 20250614
# 20250527
# 20250609
# 20250329
# 20250601
# 20250429
# 20250418
# 20250507
# 20250325
# 20250324
# 20250328
# 20250409
# 20250612
# 20250531
# 20250530
# 20250602
# 20250526
# 20250414
# 20250404
# 20250613
# 20250326
# 20250327
# 20250516
# 20250423
# 20250511
# 20250509
# 20250425
# 20250402
# 20250515
# 20250424
# 20250421
# 20250514
# 20250422
